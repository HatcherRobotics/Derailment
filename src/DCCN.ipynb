# %%
import pandas as pd
import numpy as np
import torch
import torch.utils.data as Data
import torch.nn as nn
import torch.optim as optim
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from einops import rearrange

# %%
class my_Dataset(Data.Dataset):
    def __init__(self, features, labels):
        self.X = features
        self.y = labels

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

class WheelRailTrajectoryDataset:
    def __init__(self,label=3):
        standard_scaler = StandardScaler()
        self.raw_data1 = pd.read_csv("../dataset/curve_R400.csv")
        self.raw_data2 = pd.read_csv("../dataset/curve_R1000.csv")
        self.raw_data3 = pd.read_csv("../dataset/curve_R2000.csv")
        self.raw_data4 = pd.read_csv("../dataset/curve_R3000.csv")
        self.raw_data5 = pd.read_csv("../dataset/curve_R4000.csv")
        self.raw_data6 = pd.read_csv("../dataset/curve_R5000.csv")
        self.raw_data = pd.concat([self.raw_data1,self.raw_data2,self.raw_data3,self.raw_data4,self.raw_data5,self.raw_data6])
        self.label = label
        #标准化
        self.data = standard_scaler.fit_transform(self.raw_data)
        self.mean = standard_scaler.mean_[label]
        self.sd = math.sqrt(standard_scaler.var_[label])


    def construct_set(self, train_por=0.6,val_por=0.2,test_por=0.2, window_size=100):
        X = []
        Y = []
        list = [self.raw_data1.shape[0],self.raw_data2.shape[0],self.raw_data3.shape[0],self.raw_data4.shape[0],self.raw_data5.shape[0],self.raw_data6.shape[0]]
        num = 0
        for j in range(len(list)):
            if j!=0:
                num = num+list[j-1]
            for i in range(list[j]-window_size):
                seq = self.data[num+i:num+i+window_size+1]
                X.append(seq[0:window_size,:self.label])
                y = seq[window_size:window_size+1,self.label]
                if(y>0.6 or y<-0.6):
                    Y.append(1)
                else:
                    Y.append(0)
        X = np.array(X)
        Y = np.array(Y)
        print(X.shape)
        print(Y.shape)
        train_x,test_x,train_y,test_y = train_test_split(X,Y,test_size=test_por,train_size=train_por+val_por,shuffle=True)
        train_x,val_x,train_y,val_y =  train_test_split(train_x,train_y,test_size=val_por/(val_por+train_por),train_size=train_por/(val_por+train_por),shuffle=True)

        train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y))
        val_set = my_Dataset(torch.Tensor(val_x), torch.Tensor(val_y))
        test_set = my_Dataset(torch.Tensor(test_x), torch.Tensor(test_y))
        return train_set, val_set, test_set

TrajectoryData = WheelRailTrajectoryDataset()
train_set, val_set, test_set = TrajectoryData.construct_set()
batch_size = 256
train_loader = Data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)
# Out:
# (227406, 100, 3)
# (227406,)

# %%
def evaluate_accuracy(data_iter, net, loss,device="cuda"):
    acc_sum, n = 0.0, 0
    test_l_sum = 0.0
    for X, y in data_iter:
        X = X.to(device)
        y = y.to(device)
        y_hat = net(X)
        y_hat = y_hat.squeeze()
        acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
        l = loss(y_hat, y.long()).sum()
        test_l_sum += l.item()
        n += y.shape[0]
    return acc_sum/n, test_l_sum/n

def visualization(train_loss,val_loss,train_accuracy,val_accuracy):
    plt.figure(1)
    x1=np.linspace(0,len(train_loss),len(train_loss))
    plt.plot(x1,train_loss,label='train_loss',linewidth=1.5)
    plt.plot(x1,val_loss,label='test_loss',linewidth=1.5)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show()

    plt.figure(2)
    x2 = np.linspace(0,len(train_accuracy),len(train_accuracy))
    plt.plot(x2,train_accuracy,label='train_accuracy',linewidth=1.5)
    plt.plot(x2,val_accuracy,label='val_accuracy',linewidth=1.5)
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.legend()
    plt.show()

def evaluate_PR(data_iter, net, loss,device="cuda"):
    n = 0
    precision_sum,recall_sum,f1_score_sum = 0.0,0.0,0.0
    test_l_sum = 0.0
    for X, y in data_iter:
        X = X.to(device)
        y = y.to(device)
        y_hat = net(X)
        l = loss(y_hat, y.long()).sum()
        y_hat = y_hat.argmax(dim=1)
        y_hat = y_hat.squeeze().cpu().detach().numpy()
        y = y.cpu().detach().numpy()
        precision_sum += metrics.precision_score(y,y_hat)
        recall_sum += metrics.recall_score(y,y_hat)
        f1_score_sum += metrics.f1_score(y,y_hat)
        test_l_sum += l.item()
        #n += y.shape[0]
        n+=1
    return precision_sum/n,recall_sum/n,f1_score_sum/n

device = torch.device("cuda")
lr = 0.0001
epochs=300
loss=nn.CrossEntropyLoss()

# %%
class Embedding(nn.Module):
    def __init__(self,seq_len,channel_dim,P=1,S=1):
        super(Embedding,self).__init__()
        self.P = P
        self.S = S
        self.emb = nn.Conv1d(in_channels=1, out_channels=channel_dim,
                             kernel_size=P,padding=0,stride=S,groups=1)

    def forward(self,x):
        #input b s v
        b = x.shape[0]
        x = x.permute(0,2,1) # b v s
        x = x.unsqueeze(2)#B V 1 S
        x = rearrange(x, 'b v c s -> (b v) c s')# B*V 1 S
        out = self.emb(x) # b v c s
        out = rearrange(out, '(b v) c s -> b v c s', b=b)
        return out # b v c s
class ModernCBlock(nn.Module):
    def __init__(self,variable_dim,r,seq_len,channel_dim):
        super(ModernCBlock,self).__init__()
        #conv_s model seq
        self.conv_b1 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//2,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b2 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//4,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b3 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//5,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b4 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//10,padding='same',stride=1,groups=variable_dim*channel_dim)

        #ffn_c model channel
        self.ffn_c = nn.Sequential(
            nn.Conv1d(in_channels=variable_dim*channel_dim, out_channels=r*variable_dim*channel_dim,padding='same',kernel_size=1,groups=variable_dim),
            nn.GELU(),
            nn.Conv1d(in_channels=r*variable_dim*channel_dim, out_channels=variable_dim*channel_dim,padding='same',kernel_size=1,groups=variable_dim)
        )

        #ffn_v model variable
        self.ffn_v = nn.Sequential(
            nn.Conv1d(in_channels=variable_dim*channel_dim, out_channels=r*variable_dim*channel_dim,padding='same',kernel_size=1,groups=channel_dim),
            nn.GELU(),
            nn.Conv1d(in_channels=r*variable_dim*channel_dim, out_channels=variable_dim*channel_dim,padding='same',kernel_size=1,groups=channel_dim)
        )

        self.norm_1 = nn.LayerNorm(variable_dim*channel_dim)
        self.norm_2 = nn.LayerNorm(variable_dim*channel_dim)
        self.norm_3 = nn.LayerNorm(channel_dim*variable_dim)

    def forward(self,x):
        #input : b v c s
        v = x.shape[1]
        x = rearrange(x, 'b v c s -> b (v c) s')
        residual = x
        y1 = self.conv_b1(x)
        y2 = self.conv_b2(x)
        y3 = self.conv_b3(x)
        y4 = self.conv_b4(x)
        y = y1 + y2 +y3 + y4 + residual
        y = y.permute(0,2,1)
        y = self.norm_1(y)
        y = y.permute(0,2,1)
        y = rearrange(y,'b (v c) s -> b v c s', v=v)

        y = rearrange(y, 'b v c s -> b (v c) s')
        residual = y
        z = self.ffn_c(y) # 
        z = z + residual
        z = z.permute(0,2,1)
        z = self.norm_2(z)
        z = z.permute(0,2,1)
        z = rearrange(z,'b (v c) s -> b v c s', v=v)
        z = z.permute(0,2,1,3)

        z = rearrange(z, 'b c v s -> b (c v) s')
        residual = z
        out = self.ffn_v(z)
        out = out + residual
        out = out.permute(0,2,1)
        out = self.norm_3(out)
        out = out.permute(0,2,1)
        out = rearrange(out,'b (c v) s -> b c v s',v=v)
        out = out.permute(0,2,1,3)# b v c s
        return out

class ModernCNet(nn.Module):

    def __init__(self,num_block,r,seq_len,channel_dim,variable_dim):
        super(ModernCNet,self).__init__()
        self.emb = Embedding(seq_len,channel_dim)
        self.ModernCList = nn.ModuleList([ModernCBlock(variable_dim,r,seq_len,channel_dim) for _ in range(num_block)])
        self.classifier = nn.Sequential(
            nn.Linear(in_features=variable_dim*seq_len*channel_dim,out_features=variable_dim*seq_len*channel_dim//2),
            nn.GELU(),
            nn.Linear(in_features=variable_dim*seq_len*channel_dim//2,out_features=2),
            nn.Sigmoid()
        )
        self.flatten = nn.Flatten()

    def forward(self,x):
        x = self.emb(x) # b v c s
        #print("x:",x.shape) #256 3 6 50
        residual = x # b v c s
        features = x
        for block in self.ModernCList:
            features = block(features)
        features = features + residual
        features = self.flatten(features) # b (v*c*s)
        out = self.classifier(features)
        return out

def train(net,train_iter,val_iter,loss,num_epochs,optimizer,device="cuda"):
    net.train()
    train_loss=[]
    val_loss=[]
    train_accuracy=[]
    val_accuracy=[]
    val_acc_best = 1e-9
    for epoch in range(num_epochs):
        train_l_sum,train_acc_sum,n=0.0,0.0,0
        for X,y in train_iter:
            X = X.to(device)
            #print("X:",X.shape)
            y = y.to(device)
            #print("y:",y.shape) 
            y_hat = net(X)
            #print("y_hat:",y_hat.shape)
            #y_hat = y_hat.squeeze()
            #print("y_hat_squeeze:",y_hat.shape)
            l=loss(y_hat,y.long()).sum()
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
            train_l_sum+=l.item()
            train_acc_sum+=(y_hat.argmax(dim=1)==y).sum().item()
            n+=y.shape[0]
        net.eval()
        val_acc,val_l = evaluate_accuracy(val_iter,net,loss)
        net.train()
        train_loss.append(train_l_sum/n)
        val_loss.append(val_l)
        train_accuracy.append(train_acc_sum/n)
        val_accuracy.append(val_acc)
        if(val_acc>val_acc_best):
            val_acc_best = val_acc
            train_loss_best = train_l_sum/n
            train_acc_best = train_acc_sum/n
            epoch_best = epoch
            torch.save(net.state_dict(),"weights/DCCN_best.pt")
        print('epoch%d,loss%.4f,train acc %3f,val acc %.3f'%(epoch+1,train_l_sum/n,train_acc_sum/n,val_acc))
    print("best weight was found in epoch%d,where the train loss is %.4f,train acc is %3f,val acc is %.3f"%(epoch_best,train_loss_best,train_acc_best,val_acc_best))
    return train_loss,val_loss,train_accuracy,val_accuracy

net = ModernCNet(3,2,100,6,3)
net.to(device)
optimizer=optim.Adam(net.parameters(),lr)

train_loss,val_loss,train_accuracy,val_accuracy=train(net,train_loader,val_loader,loss,epochs,optimizer)
visualization(train_loss,val_loss,train_accuracy,val_accuracy)
net.load_state_dict(torch.load("weights/DCCN_best.pt"))
test_acc,_ = evaluate_accuracy(test_loader,net,loss)
print("Accuracy on test set : %.3f"%(test_acc))
test_precision,test_recall,test_f1_score = evaluate_PR(test_loader,net,loss)
print("test precision:",test_precision," test recall:",test_recall," test f1_score:",test_f1_score)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\conv.py:306: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ..\aten\src\ATen\native\Convolution.cpp:1009.)
#   return F.conv1d(input, weight, bias, self.stride,
# epoch1,loss0.0019,train acc 0.798762,val acc 0.848
# epoch2,loss0.0017,train acc 0.869581,val acc 0.887
# epoch3,loss0.0016,train acc 0.893254,val acc 0.906
# epoch4,loss0.0016,train acc 0.905949,val acc 0.904
# epoch5,loss0.0015,train acc 0.915472,val acc 0.922
# epoch6,loss0.0015,train acc 0.921045,val acc 0.919
# epoch7,loss0.0015,train acc 0.924812,val acc 0.929
# epoch8,loss0.0015,train acc 0.928109,val acc 0.922
# epoch9,loss0.0015,train acc 0.930936,val acc 0.927
# epoch10,loss0.0015,train acc 0.933645,val acc 0.938
# epoch11,loss0.0015,train acc 0.935246,val acc 0.941
# epoch12,loss0.0015,train acc 0.937184,val acc 0.940
# epoch13,loss0.0015,train acc 0.937720,val acc 0.939
# epoch14,loss0.0015,train acc 0.938829,val acc 0.928
# epoch15,loss0.0014,train acc 0.940929,val acc 0.946
# epoch16,loss0.0014,train acc 0.942992,val acc 0.941
# epoch17,loss0.0014,train acc 0.942177,val acc 0.947
# epoch18,loss0.0014,train acc 0.942581,val acc 0.941
# epoch19,loss0.0014,train acc 0.945026,val acc 0.943
# epoch20,loss0.0014,train acc 0.945342,val acc 0.946
# epoch21,loss0.0014,train acc 0.946120,val acc 0.946
# epoch22,loss0.0014,train acc 0.946722,val acc 0.948
# epoch23,loss0.0014,train acc 0.949799,val acc 0.942
# epoch24,loss0.0014,train acc 0.949043,val acc 0.947
# epoch25,loss0.0014,train acc 0.948888,val acc 0.954
# epoch26,loss0.0014,train acc 0.950577,val acc 0.949
# epoch27,loss0.0014,train acc 0.950746,val acc 0.956
# epoch28,loss0.0014,train acc 0.952207,val acc 0.954
# epoch29,loss0.0014,train acc 0.952839,val acc 0.954
# epoch30,loss0.0014,train acc 0.954366,val acc 0.957
# epoch31,loss0.0014,train acc 0.953081,val acc 0.955
# epoch32,loss0.0014,train acc 0.953786,val acc 0.955
# epoch33,loss0.0014,train acc 0.957266,val acc 0.942
# epoch34,loss0.0014,train acc 0.955908,val acc 0.952
# epoch35,loss0.0014,train acc 0.956848,val acc 0.935
# epoch36,loss0.0014,train acc 0.956143,val acc 0.961
# epoch37,loss0.0014,train acc 0.958639,val acc 0.956
# epoch38,loss0.0014,train acc 0.958522,val acc 0.953
# epoch39,loss0.0014,train acc 0.959293,val acc 0.960
# epoch40,loss0.0014,train acc 0.958889,val acc 0.959
# epoch41,loss0.0014,train acc 0.959388,val acc 0.959
# epoch42,loss0.0014,train acc 0.961114,val acc 0.959
# epoch43,loss0.0014,train acc 0.960681,val acc 0.962
# epoch44,loss0.0014,train acc 0.960262,val acc 0.957
# epoch45,loss0.0014,train acc 0.962494,val acc 0.959
# epoch46,loss0.0014,train acc 0.962707,val acc 0.959
# epoch47,loss0.0014,train acc 0.963992,val acc 0.964
# epoch48,loss0.0014,train acc 0.963309,val acc 0.964
# epoch49,loss0.0014,train acc 0.963933,val acc 0.958
# epoch50,loss0.0014,train acc 0.964770,val acc 0.950
# epoch51,loss0.0014,train acc 0.966254,val acc 0.964
# epoch52,loss0.0014,train acc 0.965475,val acc 0.960
# epoch53,loss0.0014,train acc 0.965967,val acc 0.963
# epoch54,loss0.0014,train acc 0.965380,val acc 0.968
# epoch55,loss0.0014,train acc 0.967553,val acc 0.965
# epoch56,loss0.0014,train acc 0.964976,val acc 0.968
# epoch57,loss0.0013,train acc 0.967795,val acc 0.968
# epoch58,loss0.0013,train acc 0.968706,val acc 0.956
# epoch59,loss0.0013,train acc 0.967766,val acc 0.968
# epoch60,loss0.0013,train acc 0.967913,val acc 0.970
# epoch61,loss0.0013,train acc 0.969697,val acc 0.970
# epoch62,loss0.0013,train acc 0.969749,val acc 0.971
# epoch63,loss0.0013,train acc 0.970468,val acc 0.969
# epoch64,loss0.0013,train acc 0.970116,val acc 0.970
# epoch65,loss0.0013,train acc 0.970417,val acc 0.967
# epoch66,loss0.0013,train acc 0.972069,val acc 0.969
# epoch67,loss0.0013,train acc 0.971327,val acc 0.965
# epoch68,loss0.0013,train acc 0.971871,val acc 0.971
# epoch69,loss0.0013,train acc 0.972128,val acc 0.972
# epoch70,loss0.0013,train acc 0.971012,val acc 0.971
# epoch71,loss0.0013,train acc 0.973119,val acc 0.971
# epoch72,loss0.0013,train acc 0.972781,val acc 0.971
# epoch73,loss0.0013,train acc 0.973618,val acc 0.972
# epoch74,loss0.0013,train acc 0.973699,val acc 0.973
# epoch75,loss0.0013,train acc 0.973574,val acc 0.970
# epoch76,loss0.0013,train acc 0.972781,val acc 0.973
# epoch77,loss0.0013,train acc 0.974477,val acc 0.972
# epoch78,loss0.0013,train acc 0.974925,val acc 0.975
# epoch79,loss0.0013,train acc 0.975799,val acc 0.967
# epoch80,loss0.0013,train acc 0.975513,val acc 0.975
# epoch81,loss0.0013,train acc 0.973618,val acc 0.974
# epoch82,loss0.0013,train acc 0.975711,val acc 0.975
# epoch83,loss0.0013,train acc 0.976996,val acc 0.974
# epoch84,loss0.0013,train acc 0.976805,val acc 0.972
# epoch85,loss0.0013,train acc 0.977950,val acc 0.976
# epoch86,loss0.0013,train acc 0.976761,val acc 0.976
# epoch87,loss0.0013,train acc 0.977532,val acc 0.975
# epoch88,loss0.0013,train acc 0.977480,val acc 0.972
# epoch89,loss0.0013,train acc 0.977040,val acc 0.975
# epoch90,loss0.0013,train acc 0.977914,val acc 0.970
# epoch91,loss0.0013,train acc 0.977076,val acc 0.975
# epoch92,loss0.0013,train acc 0.978472,val acc 0.972
# epoch93,loss0.0013,train acc 0.977238,val acc 0.973
# epoch94,loss0.0013,train acc 0.977833,val acc 0.974
# epoch95,loss0.0013,train acc 0.978897,val acc 0.976
# epoch96,loss0.0013,train acc 0.979235,val acc 0.973
# epoch97,loss0.0013,train acc 0.978479,val acc 0.975
# epoch98,loss0.0013,train acc 0.979455,val acc 0.978
# epoch99,loss0.0013,train acc 0.980153,val acc 0.978
# epoch100,loss0.0013,train acc 0.980109,val acc 0.978
# epoch101,loss0.0013,train acc 0.980425,val acc 0.974
# epoch102,loss0.0013,train acc 0.980036,val acc 0.979
# epoch103,loss0.0013,train acc 0.980293,val acc 0.975
# epoch104,loss0.0013,train acc 0.981093,val acc 0.980
# epoch105,loss0.0013,train acc 0.979646,val acc 0.972
# epoch106,loss0.0013,train acc 0.981232,val acc 0.977
# epoch107,loss0.0013,train acc 0.980990,val acc 0.977
# epoch108,loss0.0013,train acc 0.980630,val acc 0.980
# epoch109,loss0.0013,train acc 0.981276,val acc 0.979
# epoch110,loss0.0013,train acc 0.981247,val acc 0.978
# epoch111,loss0.0013,train acc 0.982180,val acc 0.969
# epoch112,loss0.0013,train acc 0.981989,val acc 0.980
# epoch113,loss0.0013,train acc 0.982224,val acc 0.980
# epoch114,loss0.0013,train acc 0.981768,val acc 0.980
# epoch115,loss0.0013,train acc 0.982437,val acc 0.981
# epoch116,loss0.0013,train acc 0.982576,val acc 0.981
# epoch117,loss0.0013,train acc 0.983376,val acc 0.977
# epoch118,loss0.0013,train acc 0.983061,val acc 0.978
# epoch119,loss0.0013,train acc 0.982598,val acc 0.980
# epoch120,loss0.0013,train acc 0.983641,val acc 0.979
# epoch121,loss0.0013,train acc 0.983134,val acc 0.979
# epoch122,loss0.0013,train acc 0.983031,val acc 0.976
# epoch123,loss0.0013,train acc 0.982635,val acc 0.976
# epoch124,loss0.0013,train acc 0.983545,val acc 0.977
# epoch125,loss0.0013,train acc 0.983450,val acc 0.979
# epoch126,loss0.0013,train acc 0.983810,val acc 0.982
# epoch127,loss0.0013,train acc 0.984008,val acc 0.982
# epoch128,loss0.0013,train acc 0.983788,val acc 0.981
# epoch129,loss0.0013,train acc 0.984030,val acc 0.981
# epoch130,loss0.0013,train acc 0.984882,val acc 0.982
# epoch131,loss0.0013,train acc 0.985271,val acc 0.981
# epoch132,loss0.0013,train acc 0.984559,val acc 0.981
# epoch133,loss0.0013,train acc 0.984889,val acc 0.982
# epoch134,loss0.0013,train acc 0.984676,val acc 0.981
# epoch135,loss0.0013,train acc 0.984375,val acc 0.977
# epoch136,loss0.0013,train acc 0.985719,val acc 0.983
# epoch137,loss0.0013,train acc 0.984573,val acc 0.981
# epoch138,loss0.0013,train acc 0.985954,val acc 0.982
# epoch139,loss0.0013,train acc 0.985587,val acc 0.976
# epoch140,loss0.0013,train acc 0.985645,val acc 0.975
# epoch141,loss0.0013,train acc 0.985366,val acc 0.980
# epoch142,loss0.0013,train acc 0.985638,val acc 0.982
# epoch143,loss0.0013,train acc 0.986424,val acc 0.981
# epoch144,loss0.0013,train acc 0.985403,val acc 0.980
# epoch145,loss0.0013,train acc 0.986034,val acc 0.983
# epoch146,loss0.0013,train acc 0.985653,val acc 0.981
# epoch147,loss0.0013,train acc 0.985961,val acc 0.979
# epoch148,loss0.0013,train acc 0.985440,val acc 0.981
# epoch149,loss0.0013,train acc 0.986247,val acc 0.982
# epoch150,loss0.0013,train acc 0.986607,val acc 0.979
# epoch151,loss0.0013,train acc 0.986475,val acc 0.975
# epoch152,loss0.0013,train acc 0.986490,val acc 0.983
# epoch153,loss0.0013,train acc 0.986189,val acc 0.984
# epoch154,loss0.0013,train acc 0.986805,val acc 0.980
# epoch155,loss0.0013,train acc 0.986563,val acc 0.983
# epoch156,loss0.0013,train acc 0.987026,val acc 0.982
# epoch157,loss0.0013,train acc 0.987305,val acc 0.980
# epoch158,loss0.0013,train acc 0.986372,val acc 0.982
# epoch159,loss0.0013,train acc 0.987246,val acc 0.984
# epoch160,loss0.0013,train acc 0.986475,val acc 0.984
# epoch161,loss0.0013,train acc 0.986607,val acc 0.982
# epoch162,loss0.0013,train acc 0.987855,val acc 0.982
# epoch163,loss0.0013,train acc 0.987525,val acc 0.982
# epoch164,loss0.0013,train acc 0.987510,val acc 0.985
# epoch165,loss0.0013,train acc 0.986908,val acc 0.984
# epoch166,loss0.0013,train acc 0.987988,val acc 0.983
# epoch167,loss0.0013,train acc 0.987334,val acc 0.982
# epoch168,loss0.0013,train acc 0.987679,val acc 0.984
# epoch169,loss0.0013,train acc 0.988237,val acc 0.985
# epoch170,loss0.0013,train acc 0.987290,val acc 0.984
# epoch171,loss0.0013,train acc 0.987437,val acc 0.984
# epoch172,loss0.0013,train acc 0.988245,val acc 0.983
# epoch173,loss0.0013,train acc 0.988435,val acc 0.982
# epoch174,loss0.0013,train acc 0.988252,val acc 0.985
# epoch175,loss0.0013,train acc 0.988384,val acc 0.981
# epoch176,loss0.0013,train acc 0.987591,val acc 0.984
# epoch177,loss0.0013,train acc 0.987664,val acc 0.983
# epoch178,loss0.0013,train acc 0.987797,val acc 0.979
# epoch179,loss0.0013,train acc 0.988428,val acc 0.980
# epoch180,loss0.0013,train acc 0.988472,val acc 0.984
# epoch181,loss0.0013,train acc 0.987841,val acc 0.982
# epoch182,loss0.0013,train acc 0.988509,val acc 0.982
# epoch183,loss0.0013,train acc 0.988296,val acc 0.981
# epoch184,loss0.0013,train acc 0.988252,val acc 0.982
# epoch185,loss0.0013,train acc 0.988612,val acc 0.985
# epoch186,loss0.0013,train acc 0.989030,val acc 0.985
# epoch187,loss0.0013,train acc 0.988479,val acc 0.983
# epoch188,loss0.0013,train acc 0.988773,val acc 0.985
# epoch189,loss0.0013,train acc 0.989221,val acc 0.985
# epoch190,loss0.0013,train acc 0.988935,val acc 0.986
# epoch191,loss0.0013,train acc 0.988876,val acc 0.978
# epoch192,loss0.0013,train acc 0.988634,val acc 0.985
# epoch193,loss0.0013,train acc 0.987797,val acc 0.985
# epoch194,loss0.0013,train acc 0.989603,val acc 0.984
# epoch195,loss0.0013,train acc 0.988964,val acc 0.982
# epoch196,loss0.0013,train acc 0.988648,val acc 0.978
# epoch197,loss0.0013,train acc 0.988200,val acc 0.983
# epoch198,loss0.0013,train acc 0.989184,val acc 0.982
# epoch199,loss0.0013,train acc 0.989588,val acc 0.986
# epoch200,loss0.0013,train acc 0.989236,val acc 0.986
# epoch201,loss0.0013,train acc 0.989104,val acc 0.982
# epoch202,loss0.0013,train acc 0.990176,val acc 0.986
# epoch203,loss0.0013,train acc 0.989676,val acc 0.984
# epoch204,loss0.0013,train acc 0.988612,val acc 0.986
# epoch205,loss0.0013,train acc 0.989522,val acc 0.983
# epoch206,loss0.0013,train acc 0.989853,val acc 0.986
# epoch207,loss0.0013,train acc 0.989559,val acc 0.984
# epoch208,loss0.0013,train acc 0.989552,val acc 0.986
# epoch209,loss0.0013,train acc 0.989515,val acc 0.985
# epoch210,loss0.0013,train acc 0.989485,val acc 0.986
# epoch211,loss0.0013,train acc 0.989786,val acc 0.986
# epoch212,loss0.0013,train acc 0.989992,val acc 0.985
# epoch213,loss0.0013,train acc 0.989537,val acc 0.984
# epoch214,loss0.0013,train acc 0.989845,val acc 0.986
# epoch215,loss0.0013,train acc 0.990183,val acc 0.984
# epoch216,loss0.0013,train acc 0.989853,val acc 0.981
# epoch217,loss0.0013,train acc 0.989199,val acc 0.985
# epoch218,loss0.0013,train acc 0.990381,val acc 0.984
# epoch219,loss0.0013,train acc 0.990418,val acc 0.986
# epoch220,loss0.0013,train acc 0.990756,val acc 0.985
# epoch221,loss0.0013,train acc 0.990477,val acc 0.985
# epoch222,loss0.0013,train acc 0.989875,val acc 0.985
# epoch223,loss0.0013,train acc 0.989933,val acc 0.986
# epoch224,loss0.0013,train acc 0.990249,val acc 0.987
# epoch225,loss0.0013,train acc 0.990198,val acc 0.987
# epoch226,loss0.0013,train acc 0.990161,val acc 0.986
# epoch227,loss0.0013,train acc 0.989963,val acc 0.984
# epoch228,loss0.0013,train acc 0.990029,val acc 0.984
# epoch229,loss0.0013,train acc 0.990778,val acc 0.985
# epoch230,loss0.0013,train acc 0.990616,val acc 0.986
# epoch231,loss0.0013,train acc 0.990065,val acc 0.973
# epoch232,loss0.0013,train acc 0.990080,val acc 0.985
# epoch233,loss0.0013,train acc 0.990836,val acc 0.986
# epoch234,loss0.0013,train acc 0.990969,val acc 0.986
# epoch235,loss0.0013,train acc 0.990491,val acc 0.984
# epoch236,loss0.0013,train acc 0.991057,val acc 0.985
# epoch237,loss0.0013,train acc 0.990998,val acc 0.987
# epoch238,loss0.0013,train acc 0.990734,val acc 0.986
# epoch239,loss0.0013,train acc 0.990844,val acc 0.986
# epoch240,loss0.0013,train acc 0.990587,val acc 0.984
# epoch241,loss0.0013,train acc 0.990543,val acc 0.987
# epoch242,loss0.0013,train acc 0.991255,val acc 0.985
# epoch243,loss0.0013,train acc 0.990991,val acc 0.987
# epoch244,loss0.0013,train acc 0.990088,val acc 0.985
# epoch245,loss0.0013,train acc 0.991387,val acc 0.986
# epoch246,loss0.0013,train acc 0.990954,val acc 0.985
# epoch247,loss0.0013,train acc 0.990653,val acc 0.985
# epoch248,loss0.0013,train acc 0.990682,val acc 0.987
# epoch249,loss0.0013,train acc 0.990697,val acc 0.986
# epoch250,loss0.0013,train acc 0.990910,val acc 0.984
# epoch251,loss0.0013,train acc 0.991152,val acc 0.986
# epoch252,loss0.0013,train acc 0.991189,val acc 0.987
# epoch253,loss0.0013,train acc 0.991688,val acc 0.986
# epoch254,loss0.0013,train acc 0.991762,val acc 0.988
# epoch255,loss0.0013,train acc 0.991182,val acc 0.988
# epoch256,loss0.0013,train acc 0.991762,val acc 0.987
# epoch257,loss0.0013,train acc 0.991284,val acc 0.987
# epoch258,loss0.0013,train acc 0.991270,val acc 0.986
# epoch259,loss0.0013,train acc 0.991541,val acc 0.988
# epoch260,loss0.0013,train acc 0.991666,val acc 0.987
# epoch261,loss0.0013,train acc 0.991226,val acc 0.987
# epoch262,loss0.0013,train acc 0.991784,val acc 0.988
# epoch263,loss0.0013,train acc 0.991035,val acc 0.984
# epoch264,loss0.0013,train acc 0.991593,val acc 0.984
# epoch265,loss0.0013,train acc 0.991776,val acc 0.986
# epoch266,loss0.0013,train acc 0.991754,val acc 0.987
# epoch267,loss0.0013,train acc 0.992121,val acc 0.986
# epoch268,loss0.0013,train acc 0.991358,val acc 0.987
# epoch269,loss0.0013,train acc 0.991475,val acc 0.987
# epoch270,loss0.0013,train acc 0.992077,val acc 0.987
# epoch271,loss0.0013,train acc 0.991747,val acc 0.987
# epoch272,loss0.0013,train acc 0.991982,val acc 0.986
# epoch273,loss0.0013,train acc 0.991960,val acc 0.984
# epoch274,loss0.0013,train acc 0.992158,val acc 0.988
# epoch275,loss0.0013,train acc 0.992173,val acc 0.984
# epoch276,loss0.0013,train acc 0.991439,val acc 0.988
# epoch277,loss0.0013,train acc 0.991791,val acc 0.984
# epoch278,loss0.0013,train acc 0.992459,val acc 0.985
# epoch279,loss0.0013,train acc 0.991784,val acc 0.985
# epoch280,loss0.0013,train acc 0.992261,val acc 0.984
# epoch281,loss0.0013,train acc 0.992298,val acc 0.987
# epoch282,loss0.0013,train acc 0.991277,val acc 0.987
# epoch283,loss0.0013,train acc 0.991674,val acc 0.987
# epoch284,loss0.0013,train acc 0.992092,val acc 0.986
# epoch285,loss0.0013,train acc 0.992063,val acc 0.987
# epoch286,loss0.0013,train acc 0.991945,val acc 0.988
# epoch287,loss0.0013,train acc 0.992158,val acc 0.988
# epoch288,loss0.0013,train acc 0.992070,val acc 0.988
# epoch289,loss0.0013,train acc 0.992254,val acc 0.985
# epoch290,loss0.0013,train acc 0.992701,val acc 0.986
# epoch291,loss0.0013,train acc 0.992158,val acc 0.985
# epoch292,loss0.0013,train acc 0.992444,val acc 0.988
# epoch293,loss0.0013,train acc 0.992591,val acc 0.987
# epoch294,loss0.0013,train acc 0.992246,val acc 0.985
# epoch295,loss0.0013,train acc 0.992283,val acc 0.987
# epoch296,loss0.0013,train acc 0.992033,val acc 0.989
# epoch297,loss0.0013,train acc 0.992584,val acc 0.985
# epoch298,loss0.0013,train acc 0.992892,val acc 0.988
# epoch299,loss0.0013,train acc 0.992944,val acc 0.988
# epoch300,loss0.0013,train acc 0.992635,val acc 0.989
# best weight was found in epoch299,where the train loss is 0.0013,train acc is 0.992635,val acc is 0.989
# Accuracy on test set : 0.988
# test precision: 0.9843011562257665  test recall: 0.9863915529788818  test f1_score: 0.9852802772959809
