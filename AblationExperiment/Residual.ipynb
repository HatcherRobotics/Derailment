# %%
import pandas as pd
import numpy as np
import torch
import torch.utils.data as Data
import torch.nn as nn
import torch.optim as optim
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from einops import rearrange

# %%
class my_Dataset(Data.Dataset):
    def __init__(self, features, labels):
        self.X = features
        self.y = labels

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

class WheelRailTrajectoryDataset:
    def __init__(self,label=3):
        standard_scaler = StandardScaler()
        self.raw_data1 = pd.read_csv("../dataset/curve_R400.csv")
        self.raw_data2 = pd.read_csv("../dataset/curve_R1000.csv")
        self.raw_data3 = pd.read_csv("../dataset/curve_R2000.csv")
        self.raw_data4 = pd.read_csv("../dataset/curve_R3000.csv")
        self.raw_data5 = pd.read_csv("../dataset/curve_R4000.csv")
        self.raw_data6 = pd.read_csv("../dataset/curve_R5000.csv")
        self.raw_data = pd.concat([self.raw_data1,self.raw_data2,self.raw_data3,self.raw_data4,self.raw_data5,self.raw_data6])
        self.label = label
        #标准化
        self.data = standard_scaler.fit_transform(self.raw_data)
        self.mean = standard_scaler.mean_[label]
        self.sd = math.sqrt(standard_scaler.var_[label])


    def construct_set(self, train_por=0.6,val_por=0.2,test_por=0.2, window_size=100):
        X = []
        Y = []
        list = [self.raw_data1.shape[0],self.raw_data2.shape[0],self.raw_data3.shape[0],self.raw_data4.shape[0],self.raw_data5.shape[0],self.raw_data6.shape[0]]
        num = 0
        for j in range(len(list)):
            if j!=0:
                num = num+list[j-1]
            for i in range(list[j]-window_size):
                seq = self.data[num+i:num+i+window_size+1]
                X.append(seq[0:window_size,:self.label])
                y = seq[window_size:window_size+1,self.label]
                if(y>0.6 or y<-0.6):
                    Y.append(1)
                else:
                    Y.append(0)
        X = np.array(X)
        Y = np.array(Y)
        print(X.shape)
        print(Y.shape)
        train_x,test_x,train_y,test_y = train_test_split(X,Y,test_size=test_por,train_size=train_por+val_por,shuffle=True)
        train_x,val_x,train_y,val_y =  train_test_split(train_x,train_y,test_size=val_por/(val_por+train_por),train_size=train_por/(val_por+train_por),shuffle=True)

        train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y))
        val_set = my_Dataset(torch.Tensor(val_x), torch.Tensor(val_y))
        test_set = my_Dataset(torch.Tensor(test_x), torch.Tensor(test_y))
        return train_set, val_set, test_set

TrajectoryData = WheelRailTrajectoryDataset()
train_set, val_set, test_set = TrajectoryData.construct_set()
batch_size = 256
train_loader = Data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)
# Out:
# (227406, 100, 3)
# (227406,)

# %%
def evaluate_accuracy(data_iter, net, loss,device="cuda"):
    acc_sum, n = 0.0, 0
    test_l_sum = 0.0
    for X, y in data_iter:
        X = X.to(device)
        y = y.to(device)
        y_hat = net(X)
        y_hat = y_hat.squeeze()
        acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
        l = loss(y_hat, y.long()).sum()
        test_l_sum += l.item()
        n += y.shape[0]
    return acc_sum/n, test_l_sum/n

def visualization(train_loss,val_loss,train_accuracy,val_accuracy):
    plt.figure(1)
    x1=np.linspace(0,len(train_loss),len(train_loss))
    plt.plot(x1,train_loss,label='train_loss',linewidth=1.5)
    plt.plot(x1,val_loss,label='test_loss',linewidth=1.5)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show()

    plt.figure(2)
    x2 = np.linspace(0,len(train_accuracy),len(train_accuracy))
    plt.plot(x2,train_accuracy,label='train_accuracy',linewidth=1.5)
    plt.plot(x2,val_accuracy,label='val_accuracy',linewidth=1.5)
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.legend()
    plt.show()

def evaluate_PR(data_iter, net, loss,device="cuda"):
    n = 0
    precision_sum,recall_sum,f1_score_sum = 0.0,0.0,0.0
    test_l_sum = 0.0
    for X, y in data_iter:
        X = X.to(device)
        y = y.to(device)
        y_hat = net(X)
        l = loss(y_hat, y.long()).sum()
        y_hat = y_hat.argmax(dim=1)
        y_hat = y_hat.squeeze().cpu().detach().numpy()
        y = y.cpu().detach().numpy()
        precision_sum += metrics.precision_score(y,y_hat)
        recall_sum += metrics.recall_score(y,y_hat)
        f1_score_sum += metrics.f1_score(y,y_hat)
        test_l_sum += l.item()
        #n += y.shape[0]
        n+=1
    return precision_sum/n,recall_sum/n,f1_score_sum/n
class Embedding(nn.Module):
    def __init__(self,seq_len,channel_dim,P=1,S=1):
        super(Embedding,self).__init__()
        self.P = P
        self.S = S
        self.emb = nn.Conv1d(in_channels=1, out_channels=channel_dim,
                             kernel_size=P,padding=0,stride=S,groups=1)

    def forward(self,x):
        #input b s v
        b = x.shape[0]
        x = x.permute(0,2,1) # b v s
        x = x.unsqueeze(2)#B V 1 S
        x = rearrange(x, 'b v c s -> (b v) c s')# B*V 1 S
        out = self.emb(x) # b v c s
        out = rearrange(out, '(b v) c s -> b v c s', b=b)
        return out # b v c s
device = torch.device("cuda")
lr = 0.0001
epochs=300
loss=nn.CrossEntropyLoss()

# %% [markdown]
# 1.Residual connection for each module

# %%
class ModernCBlock(nn.Module):
    def __init__(self,variable_dim,r,seq_len,channel_dim):
        super(ModernCBlock,self).__init__()
        #conv_s model seq
        self.conv_b1 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//2,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b2 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//4,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b3 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//5,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b4 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//10,padding='same',stride=1,groups=variable_dim*channel_dim)

        #ffn_c model channel
        self.ffn_c = nn.Sequential(
            nn.Conv1d(in_channels=variable_dim*channel_dim, out_channels=r*variable_dim*channel_dim,padding='same',kernel_size=1,groups=variable_dim),
            nn.GELU(),
            nn.Conv1d(in_channels=r*variable_dim*channel_dim, out_channels=variable_dim*channel_dim,padding='same',kernel_size=1,groups=variable_dim)
        )

        #ffn_v model variable
        self.ffn_v = nn.Sequential(
            nn.Conv1d(in_channels=variable_dim*channel_dim, out_channels=r*variable_dim*channel_dim,padding='same',kernel_size=1,groups=channel_dim),
            nn.GELU(),
            nn.Conv1d(in_channels=r*variable_dim*channel_dim, out_channels=variable_dim*channel_dim,padding='same',kernel_size=1,groups=channel_dim)
        )

        self.norm_1 = nn.LayerNorm(variable_dim*channel_dim)
        self.norm_2 = nn.LayerNorm(variable_dim*channel_dim)
        self.norm_3 = nn.LayerNorm(channel_dim*variable_dim)

    def forward(self,x):
        #input : b v c s
        v = x.shape[1]
        x = rearrange(x, 'b v c s -> b (v c) s')
        residual = x
        y1 = self.conv_b1(x)
        y2 = self.conv_b2(x)
        y3 = self.conv_b3(x)
        y4 = self.conv_b4(x)
        y = y1 + y2 +y3 + y4 + residual
        y = y.permute(0,2,1)
        y = self.norm_1(y)
        y = y.permute(0,2,1)
        y = rearrange(y,'b (v c) s -> b v c s', v=v)

        y = rearrange(y, 'b v c s -> b (v c) s')
        residual = y
        z = self.ffn_c(y) # 
        z = z + residual
        z = z.permute(0,2,1)
        z = self.norm_2(z)
        z = z.permute(0,2,1)
        z = rearrange(z,'b (v c) s -> b v c s', v=v)
        z = z.permute(0,2,1,3)

        z = rearrange(z, 'b c v s -> b (c v) s')
        residual = z
        out = self.ffn_v(z)
        out = out + residual
        out = out.permute(0,2,1)
        out = self.norm_3(out)
        out = out.permute(0,2,1)
        out = rearrange(out,'b (c v) s -> b c v s',v=v)
        out = out.permute(0,2,1,3)# b v c s
        return out

class ModernCNet(nn.Module):

    def __init__(self,num_block,r,seq_len,channel_dim,variable_dim):
        super(ModernCNet,self).__init__()
        self.emb = Embedding(seq_len,channel_dim)
        self.ModernCList = nn.ModuleList([ModernCBlock(variable_dim,r,seq_len,channel_dim) for _ in range(num_block)])
        self.classifier = nn.Sequential(
            nn.Linear(in_features=variable_dim*seq_len*channel_dim,out_features=variable_dim*seq_len*channel_dim//2),
            nn.GELU(),
            nn.Linear(in_features=variable_dim*seq_len*channel_dim//2,out_features=2),
            nn.Sigmoid()
        )
        self.flatten = nn.Flatten()

    def forward(self,x):
        x = self.emb(x) # b v c s
        #print("x:",x.shape) #256 3 6 50
        residual = x # b v c s
        features = x
        for block in self.ModernCList:
            features = block(features)
        features = features + residual
        features = self.flatten(features) # b (v*c*s)
        out = self.classifier(features)
        return out

def train(net,train_iter,val_iter,loss,num_epochs,optimizer,device="cuda"):
    net.train()
    train_loss=[]
    val_loss=[]
    train_accuracy=[]
    val_accuracy=[]
    val_acc_best = 1e-9
    for epoch in range(num_epochs):
        train_l_sum,train_acc_sum,n=0.0,0.0,0
        for X,y in train_iter:
            X = X.to(device)
            #print("X:",X.shape)
            y = y.to(device)
            #print("y:",y.shape) 
            y_hat = net(X)
            #print("y_hat:",y_hat.shape)
            #y_hat = y_hat.squeeze()
            #print("y_hat_squeeze:",y_hat.shape)
            l=loss(y_hat,y.long()).sum()
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
            train_l_sum+=l.item()
            train_acc_sum+=(y_hat.argmax(dim=1)==y).sum().item()
            n+=y.shape[0]
        net.eval()
        val_acc,val_l = evaluate_accuracy(val_iter,net,loss)
        net.train()
        train_loss.append(train_l_sum/n)
        val_loss.append(val_l)
        train_accuracy.append(train_acc_sum/n)
        val_accuracy.append(val_acc)
        if(val_acc>val_acc_best):
            val_acc_best = val_acc
            train_loss_best = train_l_sum/n
            train_acc_best = train_acc_sum/n
            epoch_best = epoch
            torch.save(net.state_dict(),"weights/DCCN_Residual_best.pt")
        print('epoch%d,loss%.4f,train acc %3f,val acc %.3f'%(epoch+1,train_l_sum/n,train_acc_sum/n,val_acc))
    print("best weight was found in epoch%d,where the train loss is %.4f,train acc is %3f,val acc is %.3f"%(epoch_best,train_loss_best,train_acc_best,val_acc_best))
    return train_loss,val_loss,train_accuracy,val_accuracy

net = ModernCNet(3,2,100,6,3)
net.to(device)
optimizer=optim.Adam(net.parameters(),lr)

train_loss,val_loss,train_accuracy,val_accuracy=train(net,train_loader,val_loader,loss,epochs,optimizer)
visualization(train_loss,val_loss,train_accuracy,val_accuracy)
net.load_state_dict(torch.load("weights/DCCN_Residual_best.pt"))
test_acc,_ = evaluate_accuracy(test_loader,net,loss)
print("Accuracy on test set : %.3f"%(test_acc))
test_precision,test_recall,test_f1_score = evaluate_PR(test_loader,net,loss)
print("test precision:",test_precision," test recall:",test_recall," test f1_score:",test_f1_score)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\conv.py:306: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ..\aten\src\ATen\native\Convolution.cpp:1009.)
#   return F.conv1d(input, weight, bias, self.stride,
# epoch1,loss0.0019,train acc 0.796721,val acc 0.813
# epoch2,loss0.0018,train acc 0.849932,val acc 0.846
# epoch3,loss0.0017,train acc 0.873341,val acc 0.881
# epoch4,loss0.0017,train acc 0.883459,val acc 0.892
# epoch5,loss0.0016,train acc 0.891051,val acc 0.888
# epoch6,loss0.0016,train acc 0.898827,val acc 0.898
# epoch7,loss0.0016,train acc 0.903754,val acc 0.897
# epoch8,loss0.0016,train acc 0.904150,val acc 0.909
# epoch9,loss0.0016,train acc 0.910692,val acc 0.914
# epoch10,loss0.0015,train acc 0.914496,val acc 0.915
# epoch11,loss0.0015,train acc 0.917359,val acc 0.904
# epoch12,loss0.0015,train acc 0.919599,val acc 0.926
# epoch13,loss0.0015,train acc 0.923909,val acc 0.928
# epoch14,loss0.0015,train acc 0.925429,val acc 0.928
# epoch15,loss0.0015,train acc 0.926464,val acc 0.927
# epoch16,loss0.0015,train acc 0.930040,val acc 0.931
# epoch17,loss0.0015,train acc 0.931523,val acc 0.928
# epoch18,loss0.0015,train acc 0.929827,val acc 0.920
# epoch19,loss0.0015,train acc 0.932705,val acc 0.933
# epoch20,loss0.0015,train acc 0.934556,val acc 0.938
# epoch21,loss0.0015,train acc 0.934108,val acc 0.936
# epoch22,loss0.0015,train acc 0.937427,val acc 0.932
# epoch23,loss0.0015,train acc 0.938425,val acc 0.939
# epoch24,loss0.0015,train acc 0.939137,val acc 0.942
# epoch25,loss0.0015,train acc 0.939864,val acc 0.919
# epoch26,loss0.0015,train acc 0.938726,val acc 0.937
# epoch27,loss0.0015,train acc 0.939152,val acc 0.938
# epoch28,loss0.0014,train acc 0.942030,val acc 0.933
# epoch29,loss0.0014,train acc 0.943954,val acc 0.947
# epoch30,loss0.0014,train acc 0.943587,val acc 0.945
# epoch31,loss0.0014,train acc 0.944006,val acc 0.932
# epoch32,loss0.0014,train acc 0.944703,val acc 0.944
# epoch33,loss0.0014,train acc 0.943264,val acc 0.940
# epoch34,loss0.0014,train acc 0.945379,val acc 0.938
# epoch35,loss0.0014,train acc 0.945746,val acc 0.950
# epoch36,loss0.0014,train acc 0.947758,val acc 0.939
# epoch37,loss0.0014,train acc 0.945188,val acc 0.951
# epoch38,loss0.0014,train acc 0.948161,val acc 0.943
# epoch39,loss0.0014,train acc 0.946318,val acc 0.943
# epoch40,loss0.0014,train acc 0.948925,val acc 0.950
# epoch41,loss0.0014,train acc 0.948830,val acc 0.952
# epoch42,loss0.0014,train acc 0.950416,val acc 0.945
# epoch43,loss0.0014,train acc 0.951532,val acc 0.950
# epoch44,loss0.0014,train acc 0.950129,val acc 0.952
# epoch45,loss0.0014,train acc 0.952582,val acc 0.953
# epoch46,loss0.0014,train acc 0.950526,val acc 0.946
# epoch47,loss0.0014,train acc 0.951333,val acc 0.936
# epoch48,loss0.0014,train acc 0.952853,val acc 0.950
# epoch49,loss0.0014,train acc 0.954241,val acc 0.953
# epoch50,loss0.0014,train acc 0.953477,val acc 0.954
# epoch51,loss0.0014,train acc 0.956157,val acc 0.953
# epoch52,loss0.0014,train acc 0.951216,val acc 0.949
# epoch53,loss0.0014,train acc 0.954498,val acc 0.958
# epoch54,loss0.0014,train acc 0.955416,val acc 0.961
# epoch55,loss0.0014,train acc 0.956180,val acc 0.958
# epoch56,loss0.0014,train acc 0.956811,val acc 0.960
# epoch57,loss0.0014,train acc 0.956591,val acc 0.925
# epoch58,loss0.0014,train acc 0.957677,val acc 0.959
# epoch59,loss0.0014,train acc 0.957413,val acc 0.932
# epoch60,loss0.0014,train acc 0.956466,val acc 0.954
# epoch61,loss0.0014,train acc 0.956525,val acc 0.950
# epoch62,loss0.0014,train acc 0.956481,val acc 0.962
# epoch63,loss0.0014,train acc 0.959733,val acc 0.955
# epoch64,loss0.0014,train acc 0.957721,val acc 0.958
# epoch65,loss0.0014,train acc 0.959623,val acc 0.960
# epoch66,loss0.0014,train acc 0.959990,val acc 0.958
# epoch67,loss0.0014,train acc 0.960100,val acc 0.964
# epoch68,loss0.0014,train acc 0.959124,val acc 0.952
# epoch69,loss0.0014,train acc 0.959697,val acc 0.960
# epoch70,loss0.0014,train acc 0.961914,val acc 0.966
# epoch71,loss0.0014,train acc 0.962002,val acc 0.953
# epoch72,loss0.0014,train acc 0.962465,val acc 0.958
# epoch73,loss0.0014,train acc 0.961092,val acc 0.964
# epoch74,loss0.0014,train acc 0.962847,val acc 0.965
# epoch75,loss0.0014,train acc 0.962501,val acc 0.965
# epoch76,loss0.0014,train acc 0.963192,val acc 0.956
# epoch77,loss0.0014,train acc 0.962942,val acc 0.965
# epoch78,loss0.0014,train acc 0.961921,val acc 0.965
# epoch79,loss0.0014,train acc 0.965519,val acc 0.964
# epoch80,loss0.0014,train acc 0.962164,val acc 0.958
# epoch81,loss0.0014,train acc 0.963823,val acc 0.966
# epoch82,loss0.0014,train acc 0.965754,val acc 0.968
# epoch83,loss0.0014,train acc 0.966643,val acc 0.962
# epoch84,loss0.0014,train acc 0.964021,val acc 0.954
# epoch85,loss0.0014,train acc 0.965835,val acc 0.935
# epoch86,loss0.0014,train acc 0.966437,val acc 0.968
# epoch87,loss0.0014,train acc 0.967817,val acc 0.966
# epoch88,loss0.0013,train acc 0.968045,val acc 0.969
# epoch89,loss0.0014,train acc 0.965497,val acc 0.970
# epoch90,loss0.0014,train acc 0.967781,val acc 0.967
# epoch91,loss0.0013,train acc 0.967964,val acc 0.965
# epoch92,loss0.0013,train acc 0.967972,val acc 0.968
# epoch93,loss0.0013,train acc 0.968530,val acc 0.968
# epoch94,loss0.0013,train acc 0.968471,val acc 0.961
# epoch95,loss0.0013,train acc 0.968765,val acc 0.969
# epoch96,loss0.0013,train acc 0.969638,val acc 0.969
# epoch97,loss0.0013,train acc 0.969631,val acc 0.969
# epoch98,loss0.0013,train acc 0.968853,val acc 0.972
# epoch99,loss0.0013,train acc 0.968317,val acc 0.960
# epoch100,loss0.0013,train acc 0.970211,val acc 0.972
# epoch101,loss0.0013,train acc 0.968361,val acc 0.971
# epoch102,loss0.0013,train acc 0.971188,val acc 0.968
# epoch103,loss0.0013,train acc 0.970336,val acc 0.968
# epoch104,loss0.0013,train acc 0.970586,val acc 0.959
# epoch105,loss0.0013,train acc 0.970189,val acc 0.971
# epoch106,loss0.0013,train acc 0.971951,val acc 0.970
# epoch107,loss0.0013,train acc 0.972891,val acc 0.962
# epoch108,loss0.0013,train acc 0.971951,val acc 0.971
# epoch109,loss0.0013,train acc 0.971871,val acc 0.967
# epoch110,loss0.0013,train acc 0.971951,val acc 0.971
# epoch111,loss0.0013,train acc 0.973581,val acc 0.972
# epoch112,loss0.0013,train acc 0.972671,val acc 0.972
# epoch113,loss0.0013,train acc 0.972443,val acc 0.975
# epoch114,loss0.0013,train acc 0.973442,val acc 0.962
# epoch115,loss0.0013,train acc 0.973023,val acc 0.976
# epoch116,loss0.0013,train acc 0.973706,val acc 0.974
# epoch117,loss0.0013,train acc 0.973618,val acc 0.967
# epoch118,loss0.0013,train acc 0.974191,val acc 0.970
# epoch119,loss0.0013,train acc 0.974426,val acc 0.975
# epoch120,loss0.0013,train acc 0.973273,val acc 0.977
# epoch121,loss0.0013,train acc 0.975505,val acc 0.966
# epoch122,loss0.0013,train acc 0.974844,val acc 0.961
# epoch123,loss0.0013,train acc 0.975432,val acc 0.976
# epoch124,loss0.0013,train acc 0.975424,val acc 0.968
# epoch125,loss0.0013,train acc 0.975285,val acc 0.972
# epoch126,loss0.0013,train acc 0.975050,val acc 0.974
# epoch127,loss0.0013,train acc 0.975946,val acc 0.975
# epoch128,loss0.0013,train acc 0.976254,val acc 0.976
# epoch129,loss0.0013,train acc 0.975623,val acc 0.972
# epoch130,loss0.0013,train acc 0.976562,val acc 0.964
# epoch131,loss0.0013,train acc 0.976658,val acc 0.975
# epoch132,loss0.0013,train acc 0.976504,val acc 0.960
# epoch133,loss0.0013,train acc 0.975615,val acc 0.971
# epoch134,loss0.0013,train acc 0.977612,val acc 0.978
# epoch135,loss0.0013,train acc 0.976687,val acc 0.962
# epoch136,loss0.0013,train acc 0.976629,val acc 0.976
# epoch137,loss0.0013,train acc 0.978376,val acc 0.977
# epoch138,loss0.0013,train acc 0.977664,val acc 0.970
# epoch139,loss0.0013,train acc 0.976085,val acc 0.978
# epoch140,loss0.0013,train acc 0.976680,val acc 0.978
# epoch141,loss0.0013,train acc 0.976783,val acc 0.976
# epoch142,loss0.0013,train acc 0.978104,val acc 0.974
# epoch143,loss0.0013,train acc 0.977326,val acc 0.976
# epoch144,loss0.0013,train acc 0.978508,val acc 0.977
# epoch145,loss0.0013,train acc 0.978677,val acc 0.965
# epoch146,loss0.0013,train acc 0.978376,val acc 0.961
# epoch147,loss0.0013,train acc 0.978009,val acc 0.978
# epoch148,loss0.0013,train acc 0.979588,val acc 0.972
# epoch149,loss0.0013,train acc 0.978758,val acc 0.980
# epoch150,loss0.0013,train acc 0.978883,val acc 0.970
# epoch151,loss0.0013,train acc 0.978795,val acc 0.978
# epoch152,loss0.0013,train acc 0.977803,val acc 0.977
# epoch153,loss0.0013,train acc 0.979771,val acc 0.976
# epoch154,loss0.0013,train acc 0.979595,val acc 0.979
# epoch155,loss0.0013,train acc 0.979316,val acc 0.977
# epoch156,loss0.0013,train acc 0.978824,val acc 0.977
# epoch157,loss0.0013,train acc 0.979712,val acc 0.974
# epoch158,loss0.0013,train acc 0.979103,val acc 0.980
# epoch159,loss0.0013,train acc 0.979522,val acc 0.976
# epoch160,loss0.0013,train acc 0.980080,val acc 0.977
# epoch161,loss0.0013,train acc 0.979999,val acc 0.977
# epoch162,loss0.0013,train acc 0.980050,val acc 0.977
# epoch163,loss0.0013,train acc 0.979154,val acc 0.974
# epoch164,loss0.0013,train acc 0.981027,val acc 0.975
# epoch165,loss0.0013,train acc 0.980102,val acc 0.981
# epoch166,loss0.0013,train acc 0.980586,val acc 0.981
# epoch167,loss0.0013,train acc 0.981071,val acc 0.982
# epoch168,loss0.0013,train acc 0.981754,val acc 0.981
# epoch169,loss0.0013,train acc 0.980550,val acc 0.979
# epoch170,loss0.0013,train acc 0.981930,val acc 0.974
# epoch171,loss0.0013,train acc 0.981996,val acc 0.979
# epoch172,loss0.0013,train acc 0.982209,val acc 0.981
# epoch173,loss0.0013,train acc 0.981431,val acc 0.981
# epoch174,loss0.0013,train acc 0.982605,val acc 0.978
# epoch175,loss0.0013,train acc 0.981790,val acc 0.980
# epoch176,loss0.0013,train acc 0.981379,val acc 0.982
# epoch177,loss0.0013,train acc 0.980439,val acc 0.973
# epoch178,loss0.0013,train acc 0.981717,val acc 0.978
# epoch179,loss0.0013,train acc 0.982055,val acc 0.981
# epoch180,loss0.0013,train acc 0.982158,val acc 0.980
# epoch181,loss0.0013,train acc 0.982826,val acc 0.981
# epoch182,loss0.0013,train acc 0.981893,val acc 0.978
# epoch183,loss0.0013,train acc 0.982855,val acc 0.979
# epoch184,loss0.0013,train acc 0.981644,val acc 0.979
# epoch185,loss0.0013,train acc 0.982591,val acc 0.980
# epoch186,loss0.0013,train acc 0.983222,val acc 0.982
# epoch187,loss0.0013,train acc 0.983068,val acc 0.979
# epoch188,loss0.0013,train acc 0.982774,val acc 0.976
# epoch189,loss0.0013,train acc 0.983002,val acc 0.980
# epoch190,loss0.0013,train acc 0.983112,val acc 0.975
# epoch191,loss0.0013,train acc 0.984492,val acc 0.980
# epoch192,loss0.0013,train acc 0.982282,val acc 0.982
# epoch193,loss0.0013,train acc 0.983281,val acc 0.974
# epoch194,loss0.0013,train acc 0.983420,val acc 0.979
# epoch195,loss0.0013,train acc 0.983332,val acc 0.973
# epoch196,loss0.0013,train acc 0.983186,val acc 0.981
# epoch197,loss0.0013,train acc 0.984661,val acc 0.982
# epoch198,loss0.0013,train acc 0.982517,val acc 0.983
# epoch199,loss0.0013,train acc 0.983699,val acc 0.980
# epoch200,loss0.0013,train acc 0.984147,val acc 0.980
# epoch201,loss0.0013,train acc 0.984404,val acc 0.978
# epoch202,loss0.0013,train acc 0.984507,val acc 0.983
# epoch203,loss0.0013,train acc 0.985153,val acc 0.983
# epoch204,loss0.0013,train acc 0.982561,val acc 0.977
# epoch205,loss0.0013,train acc 0.983912,val acc 0.981
# epoch206,loss0.0013,train acc 0.984926,val acc 0.982
# epoch207,loss0.0013,train acc 0.984147,val acc 0.983
# epoch208,loss0.0013,train acc 0.984691,val acc 0.985
# epoch209,loss0.0013,train acc 0.984221,val acc 0.983
# epoch210,loss0.0013,train acc 0.984735,val acc 0.984
# epoch211,loss0.0013,train acc 0.984845,val acc 0.980
# epoch212,loss0.0013,train acc 0.984360,val acc 0.982
# epoch213,loss0.0013,train acc 0.983699,val acc 0.983
# epoch214,loss0.0013,train acc 0.985205,val acc 0.981
# epoch215,loss0.0013,train acc 0.984926,val acc 0.983
# epoch216,loss0.0013,train acc 0.984867,val acc 0.977
# epoch217,loss0.0013,train acc 0.984926,val acc 0.977
# epoch218,loss0.0013,train acc 0.985998,val acc 0.982
# epoch219,loss0.0013,train acc 0.985330,val acc 0.982
# epoch220,loss0.0013,train acc 0.984735,val acc 0.983
# epoch221,loss0.0013,train acc 0.984485,val acc 0.975
# epoch222,loss0.0013,train acc 0.985197,val acc 0.984
# epoch223,loss0.0013,train acc 0.985755,val acc 0.985
# epoch224,loss0.0013,train acc 0.985704,val acc 0.979
# epoch225,loss0.0013,train acc 0.985601,val acc 0.980
# epoch226,loss0.0013,train acc 0.984683,val acc 0.983
# epoch227,loss0.0013,train acc 0.985601,val acc 0.985
# epoch228,loss0.0013,train acc 0.986233,val acc 0.980
# epoch229,loss0.0013,train acc 0.985374,val acc 0.981
# epoch230,loss0.0013,train acc 0.984918,val acc 0.984
# epoch231,loss0.0013,train acc 0.986167,val acc 0.977
# epoch232,loss0.0013,train acc 0.985454,val acc 0.981
# epoch233,loss0.0013,train acc 0.984940,val acc 0.984
# epoch234,loss0.0013,train acc 0.985073,val acc 0.984
# epoch235,loss0.0013,train acc 0.986820,val acc 0.980
# epoch236,loss0.0013,train acc 0.985535,val acc 0.970
# epoch237,loss0.0013,train acc 0.986233,val acc 0.985
# epoch238,loss0.0013,train acc 0.985961,val acc 0.984
# epoch239,loss0.0013,train acc 0.986857,val acc 0.982
# epoch240,loss0.0013,train acc 0.986335,val acc 0.971
# epoch241,loss0.0013,train acc 0.986137,val acc 0.980
# epoch242,loss0.0013,train acc 0.986012,val acc 0.982
# epoch243,loss0.0013,train acc 0.985271,val acc 0.983
# epoch244,loss0.0013,train acc 0.987195,val acc 0.983
# epoch245,loss0.0013,train acc 0.985572,val acc 0.985
# epoch246,loss0.0013,train acc 0.986974,val acc 0.974
# epoch247,loss0.0013,train acc 0.987187,val acc 0.966
# epoch248,loss0.0013,train acc 0.986798,val acc 0.984
# epoch249,loss0.0013,train acc 0.986761,val acc 0.984
# epoch250,loss0.0013,train acc 0.986570,val acc 0.985
# epoch251,loss0.0013,train acc 0.987187,val acc 0.985
# epoch252,loss0.0013,train acc 0.986020,val acc 0.984
# epoch253,loss0.0013,train acc 0.986769,val acc 0.984
# epoch254,loss0.0013,train acc 0.987797,val acc 0.986
# epoch255,loss0.0013,train acc 0.987165,val acc 0.984
# epoch256,loss0.0013,train acc 0.987165,val acc 0.986
# epoch257,loss0.0013,train acc 0.987841,val acc 0.983
# epoch258,loss0.0013,train acc 0.987562,val acc 0.985
# epoch259,loss0.0013,train acc 0.987437,val acc 0.983
# epoch260,loss0.0013,train acc 0.986563,val acc 0.983
# epoch261,loss0.0013,train acc 0.987672,val acc 0.984
# epoch262,loss0.0013,train acc 0.987231,val acc 0.981
# epoch263,loss0.0013,train acc 0.987687,val acc 0.985
# epoch264,loss0.0013,train acc 0.987378,val acc 0.985
# epoch265,loss0.0013,train acc 0.988164,val acc 0.982
# epoch266,loss0.0013,train acc 0.987393,val acc 0.982
# epoch267,loss0.0013,train acc 0.987899,val acc 0.981
# epoch268,loss0.0013,train acc 0.987936,val acc 0.986
# epoch269,loss0.0013,train acc 0.987789,val acc 0.984
# epoch270,loss0.0013,train acc 0.987385,val acc 0.977
# epoch271,loss0.0013,train acc 0.988296,val acc 0.977
# epoch272,loss0.0013,train acc 0.987958,val acc 0.983
# epoch273,loss0.0013,train acc 0.987841,val acc 0.986
# epoch274,loss0.0013,train acc 0.987848,val acc 0.980
# epoch275,loss0.0013,train acc 0.987540,val acc 0.986
# epoch276,loss0.0013,train acc 0.987855,val acc 0.985
# epoch277,loss0.0013,train acc 0.988553,val acc 0.985
# epoch278,loss0.0013,train acc 0.987731,val acc 0.982
# epoch279,loss0.0013,train acc 0.988333,val acc 0.985
# epoch280,loss0.0013,train acc 0.988369,val acc 0.985
# epoch281,loss0.0013,train acc 0.987804,val acc 0.983
# epoch282,loss0.0013,train acc 0.988061,val acc 0.986
# epoch283,loss0.0013,train acc 0.988935,val acc 0.979
# epoch284,loss0.0013,train acc 0.988032,val acc 0.986
# epoch285,loss0.0013,train acc 0.988237,val acc 0.985
# epoch286,loss0.0013,train acc 0.988817,val acc 0.984
# epoch287,loss0.0013,train acc 0.988663,val acc 0.986
# epoch288,loss0.0013,train acc 0.988773,val acc 0.982
# epoch289,loss0.0013,train acc 0.988127,val acc 0.978
# epoch290,loss0.0013,train acc 0.988399,val acc 0.985
# epoch291,loss0.0013,train acc 0.988399,val acc 0.981
# epoch292,loss0.0013,train acc 0.989199,val acc 0.986
# epoch293,loss0.0013,train acc 0.988391,val acc 0.985
# epoch294,loss0.0013,train acc 0.989228,val acc 0.984
# epoch295,loss0.0013,train acc 0.988634,val acc 0.984
# epoch296,loss0.0013,train acc 0.989118,val acc 0.979
# epoch297,loss0.0013,train acc 0.989236,val acc 0.986
# epoch298,loss0.0013,train acc 0.988663,val acc 0.984
# epoch299,loss0.0013,train acc 0.988795,val acc 0.984
# epoch300,loss0.0013,train acc 0.988729,val acc 0.985
# best weight was found in epoch296,where the train loss is 0.0013,train acc is 0.989236,val acc is 0.986
# Accuracy on test set : 0.986
# test precision: 0.9815433671166028  test recall: 0.984852620412379  test f1_score: 0.9831255714261489

# %% [markdown]
# 2.Residual connection for all three parts

# %%
class ModernCBlock(nn.Module):
    def __init__(self,variable_dim,r,seq_len,channel_dim):
        super(ModernCBlock,self).__init__()
        #conv_s model seq
        self.conv_b1 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//2,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b2 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//4,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b3 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//5,padding='same',stride=1,groups=variable_dim*channel_dim)
        self.conv_b4 =nn.Conv1d(in_channels=variable_dim*channel_dim,out_channels=variable_dim*channel_dim,kernel_size=seq_len//10,padding='same',stride=1,groups=variable_dim*channel_dim)

        #ffn_c model channel
        self.ffn_c = nn.Sequential(
            nn.Conv1d(in_channels=variable_dim*channel_dim, out_channels=r*variable_dim*channel_dim,padding='same',kernel_size=1,groups=variable_dim),
            nn.GELU(),
            nn.Conv1d(in_channels=r*variable_dim*channel_dim, out_channels=variable_dim*channel_dim,padding='same',kernel_size=1,groups=variable_dim)
        )

        #ffn_v model variable
        self.ffn_v = nn.Sequential(
            nn.Conv1d(in_channels=variable_dim*channel_dim, out_channels=r*variable_dim*channel_dim,padding='same',kernel_size=1,groups=channel_dim),
            nn.GELU(),
            nn.Conv1d(in_channels=r*variable_dim*channel_dim, out_channels=variable_dim*channel_dim,padding='same',kernel_size=1,groups=channel_dim)
        )

        self.norm = nn.LayerNorm(variable_dim*channel_dim)

    def forward(self,x):
        #input : b v c s
        v = x.shape[1]
        x = rearrange(x, 'b v c s -> b (v c) s')
        residual = x
        y1 = self.conv_b1(x)
        y2 = self.conv_b2(x)
        y3 = self.conv_b3(x)
        y4 = self.conv_b4(x)
        y = y1 + y2 +y3 + y4
        y = rearrange(y,'b (v c) s -> b v c s', v=v)
        y = rearrange(y, 'b v c s -> b (v c) s')
        z = self.ffn_c(y) # 
        z = rearrange(z,'b (v c) s -> b v c s', v=v)
        z = z.permute(0,2,1,3)
        z = rearrange(z, 'b c v s -> b (c v) s')
        out = self.ffn_v(z)
        out = out+residual
        out = out.permute(0,2,1)
        out = self.norm(out)
        out = out.permute(0,2,1)
        out = rearrange(out,'b (c v) s -> b c v s',v=v)
        out = out.permute(0,2,1,3)# b v c s
        return out

class ModernCNet(nn.Module):

    def __init__(self,num_block,r,seq_len,channel_dim,variable_dim):
        super(ModernCNet,self).__init__()
        self.emb = Embedding(seq_len,channel_dim)
        self.ModernCList = nn.ModuleList([ModernCBlock(variable_dim,r,seq_len,channel_dim) for _ in range(num_block)])
        self.classifier = nn.Sequential(
            nn.Linear(in_features=variable_dim*seq_len*channel_dim,out_features=variable_dim*seq_len*channel_dim//2),
            nn.GELU(),
            nn.Linear(in_features=variable_dim*seq_len*channel_dim//2,out_features=2),
            nn.Sigmoid()
        )
        self.flatten = nn.Flatten()

    def forward(self,x):
        x = self.emb(x) # b v c s
        #print("x:",x.shape) #256 3 6 50
        residual = x # b v c s
        features = x
        for block in self.ModernCList:
            features = block(features)
        features = features + residual
        features = self.flatten(features) # b (v*c*s)
        out = self.classifier(features)
        return out

def train(net,train_iter,val_iter,loss,num_epochs,optimizer,device="cuda"):
    net.train()
    train_loss=[]
    val_loss=[]
    train_accuracy=[]
    val_accuracy=[]
    val_acc_best = 1e-9
    for epoch in range(num_epochs):
        train_l_sum,train_acc_sum,n=0.0,0.0,0
        for X,y in train_iter:
            X = X.to(device)
            #print("X:",X.shape)
            y = y.to(device)
            #print("y:",y.shape) 
            y_hat = net(X)
            #print("y_hat:",y_hat.shape)
            #y_hat = y_hat.squeeze()
            #print("y_hat_squeeze:",y_hat.shape)
            l=loss(y_hat,y.long()).sum()
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
            train_l_sum+=l.item()
            train_acc_sum+=(y_hat.argmax(dim=1)==y).sum().item()
            n+=y.shape[0]
        net.eval()
        val_acc,val_l = evaluate_accuracy(val_iter,net,loss)
        net.train()
        train_loss.append(train_l_sum/n)
        val_loss.append(val_l)
        train_accuracy.append(train_acc_sum/n)
        val_accuracy.append(val_acc)
        if(val_acc>val_acc_best):
            val_acc_best = val_acc
            train_loss_best = train_l_sum/n
            train_acc_best = train_acc_sum/n
            epoch_best = epoch
            torch.save(net.state_dict(),"weights/DCCN_RESless_best.pt")
        print('epoch%d,loss%.4f,train acc %3f,val acc %.3f'%(epoch+1,train_l_sum/n,train_acc_sum/n,val_acc))
    print("best weight was found in epoch%d,where the train loss is %.4f,train acc is %3f,val acc is %.3f"%(epoch_best,train_loss_best,train_acc_best,val_acc_best))
    return train_loss,val_loss,train_accuracy,val_accuracy

net = ModernCNet(3,2,100,6,3)
net.to(device)
optimizer=optim.Adam(net.parameters(),lr)

train_loss,val_loss,train_accuracy,val_accuracy=train(net,train_loader,val_loader,loss,epochs,optimizer)
visualization(train_loss,val_loss,train_accuracy,val_accuracy)
net.load_state_dict(torch.load("weights/DCCN_RESless_best.pt"))
test_acc,_ = evaluate_accuracy(test_loader,net,loss)
print("Accuracy on test set : %.3f"%(test_acc))
test_precision,test_recall,test_f1_score = evaluate_PR(test_loader,net,loss)
print("test precision:",test_precision," test recall:",test_recall," test f1_score:",test_f1_score)
# Out:
# epoch1,loss0.0020,train acc 0.786852,val acc 0.812
# epoch2,loss0.0018,train acc 0.828808,val acc 0.849
# epoch3,loss0.0018,train acc 0.856291,val acc 0.867
# epoch4,loss0.0017,train acc 0.867547,val acc 0.871
# epoch5,loss0.0017,train acc 0.871329,val acc 0.874
# epoch6,loss0.0017,train acc 0.874721,val acc 0.869
# epoch7,loss0.0017,train acc 0.877629,val acc 0.880
# epoch8,loss0.0017,train acc 0.879420,val acc 0.880
# epoch9,loss0.0017,train acc 0.880757,val acc 0.883
# epoch10,loss0.0017,train acc 0.882541,val acc 0.884
# epoch11,loss0.0017,train acc 0.885375,val acc 0.886
# epoch12,loss0.0016,train acc 0.886800,val acc 0.888
# epoch13,loss0.0016,train acc 0.887732,val acc 0.888
# epoch14,loss0.0016,train acc 0.890955,val acc 0.892
# epoch15,loss0.0016,train acc 0.891528,val acc 0.895
# epoch16,loss0.0016,train acc 0.895104,val acc 0.894
# epoch17,loss0.0016,train acc 0.895530,val acc 0.899
# epoch18,loss0.0016,train acc 0.897461,val acc 0.896
# epoch19,loss0.0016,train acc 0.900141,val acc 0.900
# epoch20,loss0.0016,train acc 0.902520,val acc 0.893
# epoch21,loss0.0016,train acc 0.903805,val acc 0.900
# epoch22,loss0.0016,train acc 0.905699,val acc 0.905
# epoch23,loss0.0016,train acc 0.907542,val acc 0.912
# epoch24,loss0.0016,train acc 0.910707,val acc 0.911
# epoch25,loss0.0016,train acc 0.910957,val acc 0.914
# epoch26,loss0.0016,train acc 0.914246,val acc 0.911
# epoch27,loss0.0015,train acc 0.916258,val acc 0.918
# epoch28,loss0.0015,train acc 0.918027,val acc 0.915
# epoch29,loss0.0015,train acc 0.919518,val acc 0.918
# epoch30,loss0.0015,train acc 0.921420,val acc 0.916
# epoch31,loss0.0015,train acc 0.923872,val acc 0.916
# epoch32,loss0.0015,train acc 0.924078,val acc 0.922
# epoch33,loss0.0015,train acc 0.927162,val acc 0.923
# epoch34,loss0.0015,train acc 0.928535,val acc 0.919
# epoch35,loss0.0015,train acc 0.929702,val acc 0.930
# epoch36,loss0.0015,train acc 0.931472,val acc 0.918
# epoch37,loss0.0015,train acc 0.932911,val acc 0.924
# epoch38,loss0.0015,train acc 0.933337,val acc 0.932
# epoch39,loss0.0015,train acc 0.935774,val acc 0.922
# epoch40,loss0.0015,train acc 0.936288,val acc 0.938
# epoch41,loss0.0015,train acc 0.936773,val acc 0.939
# epoch42,loss0.0015,train acc 0.936802,val acc 0.935
# epoch43,loss0.0015,train acc 0.938866,val acc 0.931
# epoch44,loss0.0015,train acc 0.938734,val acc 0.934
# epoch45,loss0.0015,train acc 0.938954,val acc 0.941
# epoch46,loss0.0015,train acc 0.940518,val acc 0.944
# epoch47,loss0.0014,train acc 0.941641,val acc 0.936
# epoch48,loss0.0014,train acc 0.943440,val acc 0.945
# epoch49,loss0.0014,train acc 0.942559,val acc 0.933
# epoch50,loss0.0014,train acc 0.944020,val acc 0.941
# epoch51,loss0.0014,train acc 0.943925,val acc 0.943
# epoch52,loss0.0014,train acc 0.943514,val acc 0.946
# epoch53,loss0.0014,train acc 0.945026,val acc 0.945
# epoch54,loss0.0014,train acc 0.944196,val acc 0.946
# epoch55,loss0.0014,train acc 0.946289,val acc 0.948
# epoch56,loss0.0014,train acc 0.946465,val acc 0.942
# epoch57,loss0.0014,train acc 0.946436,val acc 0.947
# epoch58,loss0.0014,train acc 0.947706,val acc 0.943
# epoch59,loss0.0014,train acc 0.947941,val acc 0.947
# epoch60,loss0.0014,train acc 0.948426,val acc 0.947
# epoch61,loss0.0014,train acc 0.948697,val acc 0.952
# epoch62,loss0.0014,train acc 0.949711,val acc 0.950
# epoch63,loss0.0014,train acc 0.950996,val acc 0.954
# epoch64,loss0.0014,train acc 0.949329,val acc 0.949
# epoch65,loss0.0014,train acc 0.950717,val acc 0.946
# epoch66,loss0.0014,train acc 0.948646,val acc 0.923
# epoch67,loss0.0014,train acc 0.949821,val acc 0.949
# epoch68,loss0.0014,train acc 0.951187,val acc 0.955
# epoch69,loss0.0014,train acc 0.949821,val acc 0.950
# epoch70,loss0.0014,train acc 0.952244,val acc 0.941
# epoch71,loss0.0014,train acc 0.952795,val acc 0.952
# epoch72,loss0.0014,train acc 0.952369,val acc 0.945
# epoch73,loss0.0014,train acc 0.953558,val acc 0.950
# epoch74,loss0.0014,train acc 0.954961,val acc 0.953
# epoch75,loss0.0014,train acc 0.954828,val acc 0.939
# epoch76,loss0.0014,train acc 0.954843,val acc 0.952
# epoch77,loss0.0014,train acc 0.953969,val acc 0.941
# epoch78,loss0.0014,train acc 0.953228,val acc 0.944
# epoch79,loss0.0014,train acc 0.954498,val acc 0.948
# epoch80,loss0.0014,train acc 0.955820,val acc 0.953
# epoch81,loss0.0014,train acc 0.955005,val acc 0.952
# epoch82,loss0.0014,train acc 0.953632,val acc 0.956
# epoch83,loss0.0014,train acc 0.956363,val acc 0.957
# epoch84,loss0.0014,train acc 0.956341,val acc 0.947
# epoch85,loss0.0014,train acc 0.955790,val acc 0.952
# epoch86,loss0.0014,train acc 0.956862,val acc 0.957
# epoch87,loss0.0014,train acc 0.956862,val acc 0.957
# epoch88,loss0.0014,train acc 0.957509,val acc 0.953
# epoch89,loss0.0014,train acc 0.958309,val acc 0.959
# epoch90,loss0.0014,train acc 0.957692,val acc 0.957
# epoch91,loss0.0014,train acc 0.958551,val acc 0.954
# epoch92,loss0.0014,train acc 0.958089,val acc 0.954
# epoch93,loss0.0014,train acc 0.958324,val acc 0.959
# epoch94,loss0.0014,train acc 0.959153,val acc 0.959
# epoch95,loss0.0014,train acc 0.959153,val acc 0.962
# epoch96,loss0.0014,train acc 0.958727,val acc 0.958
# epoch97,loss0.0014,train acc 0.959660,val acc 0.958
# epoch98,loss0.0014,train acc 0.960570,val acc 0.961
# epoch99,loss0.0014,train acc 0.959888,val acc 0.957
# epoch100,loss0.0014,train acc 0.960093,val acc 0.960
# epoch101,loss0.0014,train acc 0.959807,val acc 0.955
# epoch102,loss0.0014,train acc 0.959285,val acc 0.963
# epoch103,loss0.0014,train acc 0.961613,val acc 0.958
# epoch104,loss0.0014,train acc 0.961356,val acc 0.953
# epoch105,loss0.0014,train acc 0.962017,val acc 0.957
# epoch106,loss0.0014,train acc 0.960996,val acc 0.962
# epoch107,loss0.0014,train acc 0.961584,val acc 0.956
# epoch108,loss0.0014,train acc 0.962017,val acc 0.951
# epoch109,loss0.0014,train acc 0.961694,val acc 0.958
# epoch110,loss0.0014,train acc 0.962259,val acc 0.957
# epoch111,loss0.0014,train acc 0.961855,val acc 0.958
# epoch112,loss0.0014,train acc 0.962024,val acc 0.962
# epoch113,loss0.0014,train acc 0.962634,val acc 0.960
# epoch114,loss0.0014,train acc 0.962722,val acc 0.965
# epoch115,loss0.0014,train acc 0.962736,val acc 0.963
# epoch116,loss0.0014,train acc 0.963214,val acc 0.962
# epoch117,loss0.0014,train acc 0.962546,val acc 0.964
# epoch118,loss0.0014,train acc 0.963140,val acc 0.963
# epoch119,loss0.0014,train acc 0.963412,val acc 0.965
# epoch120,loss0.0014,train acc 0.963772,val acc 0.965
# epoch121,loss0.0014,train acc 0.964043,val acc 0.964
# epoch122,loss0.0014,train acc 0.963067,val acc 0.966
# epoch123,loss0.0014,train acc 0.964021,val acc 0.955
# epoch124,loss0.0014,train acc 0.964249,val acc 0.965
# epoch125,loss0.0014,train acc 0.965769,val acc 0.963
# epoch126,loss0.0014,train acc 0.965593,val acc 0.967
# epoch127,loss0.0014,train acc 0.964969,val acc 0.953
# epoch128,loss0.0014,train acc 0.964601,val acc 0.966
# epoch129,loss0.0014,train acc 0.965453,val acc 0.960
# epoch130,loss0.0014,train acc 0.963875,val acc 0.961
# epoch131,loss0.0014,train acc 0.965740,val acc 0.966
# epoch132,loss0.0014,train acc 0.966430,val acc 0.965
# epoch133,loss0.0014,train acc 0.965527,val acc 0.951
# epoch134,loss0.0014,train acc 0.965549,val acc 0.967
# epoch135,loss0.0014,train acc 0.965424,val acc 0.964
# epoch136,loss0.0014,train acc 0.966672,val acc 0.963
# epoch137,loss0.0013,train acc 0.967414,val acc 0.969
# epoch138,loss0.0014,train acc 0.967061,val acc 0.960
# epoch139,loss0.0014,train acc 0.966768,val acc 0.968
# epoch140,loss0.0013,train acc 0.967561,val acc 0.964
# epoch141,loss0.0013,train acc 0.967612,val acc 0.967
# epoch142,loss0.0014,train acc 0.967326,val acc 0.960
# epoch143,loss0.0013,train acc 0.968192,val acc 0.961
# epoch144,loss0.0013,train acc 0.968287,val acc 0.967
# epoch145,loss0.0014,train acc 0.967076,val acc 0.970
# epoch146,loss0.0013,train acc 0.968251,val acc 0.965
# epoch147,loss0.0013,train acc 0.968089,val acc 0.964
# epoch148,loss0.0014,train acc 0.966995,val acc 0.955
# epoch149,loss0.0013,train acc 0.967950,val acc 0.964
# epoch150,loss0.0013,train acc 0.968420,val acc 0.968
# epoch151,loss0.0013,train acc 0.968662,val acc 0.959
# epoch152,loss0.0013,train acc 0.969161,val acc 0.970
# epoch153,loss0.0013,train acc 0.969969,val acc 0.969
# epoch154,loss0.0013,train acc 0.968823,val acc 0.971
# epoch155,loss0.0013,train acc 0.970468,val acc 0.969
# epoch156,loss0.0013,train acc 0.968662,val acc 0.971
# epoch157,loss0.0013,train acc 0.969095,val acc 0.964
# epoch158,loss0.0013,train acc 0.970138,val acc 0.970
# epoch159,loss0.0013,train acc 0.969426,val acc 0.958
# epoch160,loss0.0013,train acc 0.969484,val acc 0.971
# epoch161,loss0.0013,train acc 0.970182,val acc 0.969
# epoch162,loss0.0013,train acc 0.969426,val acc 0.969
# epoch163,loss0.0013,train acc 0.969800,val acc 0.970
# epoch164,loss0.0013,train acc 0.970828,val acc 0.972
# epoch165,loss0.0013,train acc 0.970512,val acc 0.972
# epoch166,loss0.0013,train acc 0.970857,val acc 0.968
# epoch167,loss0.0013,train acc 0.969616,val acc 0.972
# epoch168,loss0.0013,train acc 0.971489,val acc 0.970
# epoch169,loss0.0013,train acc 0.970556,val acc 0.967
# epoch170,loss0.0013,train acc 0.971636,val acc 0.971
# epoch171,loss0.0013,train acc 0.970813,val acc 0.967
# epoch172,loss0.0013,train acc 0.971283,val acc 0.960
# epoch173,loss0.0013,train acc 0.970630,val acc 0.968
# epoch174,loss0.0013,train acc 0.971525,val acc 0.969
# epoch175,loss0.0013,train acc 0.972186,val acc 0.960
# epoch176,loss0.0013,train acc 0.971863,val acc 0.966
# epoch177,loss0.0013,train acc 0.970630,val acc 0.971
# epoch178,loss0.0013,train acc 0.972465,val acc 0.969
# epoch179,loss0.0013,train acc 0.971261,val acc 0.968
# epoch180,loss0.0013,train acc 0.972385,val acc 0.969
# epoch181,loss0.0013,train acc 0.971929,val acc 0.971
# epoch182,loss0.0013,train acc 0.972216,val acc 0.973
# epoch183,loss0.0013,train acc 0.972568,val acc 0.963
# epoch184,loss0.0013,train acc 0.973031,val acc 0.971
# epoch185,loss0.0013,train acc 0.972039,val acc 0.973
# epoch186,loss0.0013,train acc 0.972840,val acc 0.974
# epoch187,loss0.0013,train acc 0.972385,val acc 0.966
# epoch188,loss0.0013,train acc 0.972877,val acc 0.972
# epoch189,loss0.0013,train acc 0.972017,val acc 0.972
# epoch190,loss0.0013,train acc 0.973985,val acc 0.970
# epoch191,loss0.0013,train acc 0.973567,val acc 0.975
# epoch192,loss0.0013,train acc 0.972230,val acc 0.972
# epoch193,loss0.0013,train acc 0.973405,val acc 0.972
# epoch194,loss0.0013,train acc 0.973692,val acc 0.973
# epoch195,loss0.0013,train acc 0.973288,val acc 0.972
# epoch196,loss0.0013,train acc 0.974264,val acc 0.974
# epoch197,loss0.0013,train acc 0.974543,val acc 0.971
# epoch198,loss0.0013,train acc 0.973743,val acc 0.973
# epoch199,loss0.0013,train acc 0.974433,val acc 0.974
# epoch200,loss0.0013,train acc 0.972788,val acc 0.973
# epoch201,loss0.0013,train acc 0.974668,val acc 0.975
# epoch202,loss0.0013,train acc 0.972943,val acc 0.972
# epoch203,loss0.0013,train acc 0.975542,val acc 0.965
# epoch204,loss0.0013,train acc 0.974485,val acc 0.971
# epoch205,loss0.0013,train acc 0.974653,val acc 0.971
# epoch206,loss0.0013,train acc 0.974925,val acc 0.972
# epoch207,loss0.0013,train acc 0.975057,val acc 0.975
# epoch208,loss0.0013,train acc 0.974587,val acc 0.972
# epoch209,loss0.0013,train acc 0.974308,val acc 0.970
# epoch210,loss0.0013,train acc 0.976093,val acc 0.971
# epoch211,loss0.0013,train acc 0.975476,val acc 0.974
# epoch212,loss0.0013,train acc 0.975006,val acc 0.977
# epoch213,loss0.0013,train acc 0.975028,val acc 0.972
# epoch214,loss0.0013,train acc 0.975211,val acc 0.974
# epoch215,loss0.0013,train acc 0.975043,val acc 0.973
# epoch216,loss0.0013,train acc 0.975858,val acc 0.967
# epoch217,loss0.0013,train acc 0.975593,val acc 0.966
# epoch218,loss0.0013,train acc 0.976482,val acc 0.976
# epoch219,loss0.0013,train acc 0.975608,val acc 0.967
# epoch220,loss0.0013,train acc 0.975351,val acc 0.977
# epoch221,loss0.0013,train acc 0.975520,val acc 0.974
# epoch222,loss0.0013,train acc 0.976203,val acc 0.975
# epoch223,loss0.0013,train acc 0.976012,val acc 0.974
# epoch224,loss0.0013,train acc 0.976085,val acc 0.974
# epoch225,loss0.0013,train acc 0.975968,val acc 0.974
# epoch226,loss0.0013,train acc 0.976562,val acc 0.969
# epoch227,loss0.0013,train acc 0.976034,val acc 0.974
# epoch228,loss0.0013,train acc 0.974793,val acc 0.974
# epoch229,loss0.0013,train acc 0.975762,val acc 0.971
# epoch230,loss0.0013,train acc 0.975960,val acc 0.975
# epoch231,loss0.0013,train acc 0.977899,val acc 0.974
# epoch232,loss0.0013,train acc 0.976842,val acc 0.972
# epoch233,loss0.0013,train acc 0.976482,val acc 0.974
# epoch234,loss0.0013,train acc 0.977223,val acc 0.974
# epoch235,loss0.0013,train acc 0.976173,val acc 0.976
# epoch236,loss0.0013,train acc 0.976438,val acc 0.970
# epoch237,loss0.0013,train acc 0.977275,val acc 0.971
# epoch238,loss0.0013,train acc 0.977928,val acc 0.975
# epoch239,loss0.0013,train acc 0.977554,val acc 0.973
# epoch240,loss0.0013,train acc 0.977025,val acc 0.963
# epoch241,loss0.0013,train acc 0.976585,val acc 0.975
# epoch242,loss0.0013,train acc 0.977899,val acc 0.974
# epoch243,loss0.0013,train acc 0.977319,val acc 0.974
# epoch244,loss0.0013,train acc 0.977209,val acc 0.977
# epoch245,loss0.0013,train acc 0.978148,val acc 0.977
# epoch246,loss0.0013,train acc 0.978251,val acc 0.969
# epoch247,loss0.0013,train acc 0.977840,val acc 0.978
# epoch248,loss0.0013,train acc 0.977877,val acc 0.974
# epoch249,loss0.0013,train acc 0.978310,val acc 0.978
# epoch250,loss0.0013,train acc 0.977267,val acc 0.978
# epoch251,loss0.0013,train acc 0.978545,val acc 0.974
# epoch252,loss0.0013,train acc 0.977657,val acc 0.977
# epoch253,loss0.0013,train acc 0.978361,val acc 0.974
# epoch254,loss0.0013,train acc 0.978516,val acc 0.977
# epoch255,loss0.0013,train acc 0.977884,val acc 0.979
# epoch256,loss0.0013,train acc 0.978853,val acc 0.976
# epoch257,loss0.0013,train acc 0.978134,val acc 0.967
# epoch258,loss0.0013,train acc 0.978163,val acc 0.976
# epoch259,loss0.0013,train acc 0.978420,val acc 0.976
# epoch260,loss0.0013,train acc 0.978457,val acc 0.972
# epoch261,loss0.0013,train acc 0.979441,val acc 0.978
# epoch262,loss0.0013,train acc 0.977568,val acc 0.976
# epoch263,loss0.0013,train acc 0.978662,val acc 0.971
# epoch264,loss0.0013,train acc 0.978883,val acc 0.975
# epoch265,loss0.0013,train acc 0.978472,val acc 0.977
# epoch266,loss0.0013,train acc 0.979646,val acc 0.979
# epoch267,loss0.0013,train acc 0.979705,val acc 0.977
# epoch268,loss0.0013,train acc 0.978993,val acc 0.970
# epoch269,loss0.0013,train acc 0.979206,val acc 0.975
# epoch270,loss0.0013,train acc 0.979485,val acc 0.976
# epoch271,loss0.0013,train acc 0.979030,val acc 0.979
# epoch272,loss0.0013,train acc 0.979999,val acc 0.975
# epoch273,loss0.0013,train acc 0.979154,val acc 0.975
# epoch274,loss0.0013,train acc 0.980028,val acc 0.976
# epoch275,loss0.0013,train acc 0.980131,val acc 0.978
# epoch276,loss0.0013,train acc 0.979323,val acc 0.980
# epoch277,loss0.0013,train acc 0.980006,val acc 0.976
# epoch278,loss0.0013,train acc 0.980623,val acc 0.978
# epoch279,loss0.0013,train acc 0.980337,val acc 0.978
# epoch280,loss0.0013,train acc 0.979808,val acc 0.975
# epoch281,loss0.0013,train acc 0.979265,val acc 0.978
# epoch282,loss0.0013,train acc 0.979676,val acc 0.980
# epoch283,loss0.0013,train acc 0.980388,val acc 0.980
# epoch284,loss0.0013,train acc 0.980784,val acc 0.978
# epoch285,loss0.0013,train acc 0.980505,val acc 0.975
# epoch286,loss0.0013,train acc 0.980983,val acc 0.978
# epoch287,loss0.0013,train acc 0.979646,val acc 0.979
# epoch288,loss0.0013,train acc 0.981644,val acc 0.971
# epoch289,loss0.0013,train acc 0.980293,val acc 0.978
# epoch290,loss0.0013,train acc 0.981174,val acc 0.976
# epoch291,loss0.0013,train acc 0.981754,val acc 0.975
# epoch292,loss0.0013,train acc 0.981188,val acc 0.978
# epoch293,loss0.0013,train acc 0.979925,val acc 0.974
# epoch294,loss0.0013,train acc 0.980873,val acc 0.979
# epoch295,loss0.0013,train acc 0.980931,val acc 0.980
# epoch296,loss0.0013,train acc 0.980740,val acc 0.971
# epoch297,loss0.0013,train acc 0.981600,val acc 0.977
# epoch298,loss0.0013,train acc 0.980799,val acc 0.973
# epoch299,loss0.0013,train acc 0.981945,val acc 0.972
# epoch300,loss0.0013,train acc 0.981467,val acc 0.979
# best weight was found in epoch294,where the train loss is 0.0013,train acc is 0.980931,val acc is 0.980
# Accuracy on test set : 0.980
# test precision: 0.9809623795640063  test recall: 0.9702839611239418  test f1_score: 0.975504025477719
